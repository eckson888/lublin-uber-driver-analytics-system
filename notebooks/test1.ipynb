# %%
import numpy as np
import pandas as pd

data = pd.read_csv("/home/eckson888/projekcik/data/01 - Driver Lifetime Trip Data.csv")
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 75 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   city_id                        1048 non-null   int64
#  1   currency_code                  1048 non-null   object
#  2   timezone                       1048 non-null   object
#  3   flow                           1048 non-null   object
#  4   product_type_name              1048 non-null   object
#  5   global_product_name            1048 non-null   object
#  6   request_timestamp_local        1048 non-null   object
#  7   request_timestamp_utc          1048 non-null   object
#  8   begintrip_timestamp_local      1048 non-null   object
#  9   begintrip_timestamp_utc        1048 non-null   object
#  10  dropoff_timestamp_local        1048 non-null   object
#  11  dropoff_timestamp_utc          1048 non-null   object
# ...
